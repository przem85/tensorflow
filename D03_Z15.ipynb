# %%
import tensorflow as tf
import numpy as np
import sklearn.datasets
import matplotlib.pyplot as plt
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Learning Rate Scheduling
#
#   * Po ustawieniu wartości hiperparametrowych tworzymy nie trnowalną zmienną **global_step** (zainicjowaną na 0), aby śledzić aktualny numer iteracji.
#
#   * Następnie definiujemy wykładniczo szybkość uczenia (z $\eta_0 = 0,1$ i $r = 10 000$) za pomocą funkcji
#   **Exponential_decay ()**.
#   * Następnie tworzymy optymalizator (w tym przykładzie MomentumOptimizer), wykorzystując nowej szybkości uczenia.
#   * Na koniec tworzymy operację uczenia, wywołując metodę **minimize()** optymalizatora;
#   * Ponieważ przekazujemy mu zmienną **global_step** to automatycznie otrzymamy znieniającą się szybkość

# %%
data_X, data_y = sklearn.datasets.make_moons(n_samples=1000, noise=.05)



plt.scatter(data_X[:,0],data_X[:,1],c=data_y)
plt.axis('equal')
plt.show()

# %%
n_inputs = 2
n_hidden1 = 100
n_hidden2 = 100
n_outputs = 2

array_acc_test_g = []
array_acc_test_g_s = []

array_acc_test_momentum=[]
array_acc_test_nesterov=[]
array_acc_test_ada_grad=[]
array_acc_test_RMS_prop=[]
array_acc_test_adam=[]

learning_rate = 0.01
n_epochs = 100
batch_size = 50

# %%
tf.reset_default_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

from tensorflow.contrib.layers import fully_connected

with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1", activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2", activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")      
        
    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")   
    

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)    
    
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))    
    
    
init = tf.global_variables_initializer()


with tf.Session() as sess:
    sess.run(init)
    for epoch in range(n_epochs):
        for batch_index in range(data_X.shape[0] // batch_size):
            print("\r{}%".format(100 * batch_index //  (data_X.shape[0] // batch_size) ), end="")
            
            shuffle_index = np.random.permutation(batch_size)
            X_batch, y_batch = data_X[shuffle_index], data_y[shuffle_index]
            
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: data_X, y: data_y})
        print(" ", epoch, "Train accuracy:", acc_train) 
        array_acc_test_g.append(acc_train)
# Out:
# 95%  0 Train accuracy: 0.667
# 95%  1 Train accuracy: 0.765
# 95%  2 Train accuracy: 0.839
# 95%  3 Train accuracy: 0.834
# 95%  4 Train accuracy: 0.832
# 95%  5 Train accuracy: 0.829
# 95%  6 Train accuracy: 0.832
# 95%  7 Train accuracy: 0.839
# 95%  8 Train accuracy: 0.839
# 95%  9 Train accuracy: 0.842
# 95%  10 Train accuracy: 0.84
# 95%  11 Train accuracy: 0.843
# 95%  12 Train accuracy: 0.846
# 95%  13 Train accuracy: 0.846
# 95%  14 Train accuracy: 0.848
# 95%  15 Train accuracy: 0.851
# 95%  16 Train accuracy: 0.855
# 95%  17 Train accuracy: 0.859
# 95%  18 Train accuracy: 0.86
# 95%  19 Train accuracy: 0.862
# 95%  20 Train accuracy: 0.864
# 95%  21 Train accuracy: 0.867
# 95%  22 Train accuracy: 0.869
# 95%  23 Train accuracy: 0.874
# 95%  24 Train accuracy: 0.877
# 95%  25 Train accuracy: 0.88
# 95%  26 Train accuracy: 0.881
# 95%  27 Train accuracy: 0.884
# 95%  28 Train accuracy: 0.886
# 95%  29 Train accuracy: 0.888
# 95%  30 Train accuracy: 0.888
# 95%  31 Train accuracy: 0.888
# 95%  32 Train accuracy: 0.89
# 95%  33 Train accuracy: 0.89
# 95%  34 Train accuracy: 0.89
# 95%  35 Train accuracy: 0.892
# 95%  36 Train accuracy: 0.894
# 95%  37 Train accuracy: 0.896
# 95%  38 Train accuracy: 0.896
# 95%  39 Train accuracy: 0.898
# 95%  40 Train accuracy: 0.9
# 95%  41 Train accuracy: 0.9
# 95%  42 Train accuracy: 0.9
# 95%  43 Train accuracy: 0.9
# 95%  44 Train accuracy: 0.903
# 95%  45 Train accuracy: 0.905
# 95%  46 Train accuracy: 0.905
# 95%  47 Train accuracy: 0.906
# 95%  48 Train accuracy: 0.906
# 95%  49 Train accuracy: 0.908
# 95%  50 Train accuracy: 0.908
# 95%  51 Train accuracy: 0.909
# 95%  52 Train accuracy: 0.911
# 95%  53 Train accuracy: 0.909
# 95%  54 Train accuracy: 0.912
# 95%  55 Train accuracy: 0.913
# 95%  56 Train accuracy: 0.911
# 95%  57 Train accuracy: 0.911
# 95%  58 Train accuracy: 0.911
# 95%  59 Train accuracy: 0.91
# 95%  60 Train accuracy: 0.91
# 95%  61 Train accuracy: 0.911
# 95%  62 Train accuracy: 0.912
# 95%  63 Train accuracy: 0.912
# 95%  64 Train accuracy: 0.91
# 95%  65 Train accuracy: 0.91
# 95%  66 Train accuracy: 0.91
# 95%  67 Train accuracy: 0.911
# 95%  68 Train accuracy: 0.912
# 95%  69 Train accuracy: 0.913
# 95%  70 Train accuracy: 0.913
# 95%  71 Train accuracy: 0.912
# 95%  72 Train accuracy: 0.912
# 95%  73 Train accuracy: 0.911
# 95%  74 Train accuracy: 0.911
# 95%  75 Train accuracy: 0.911
# 95%  76 Train accuracy: 0.914
# 95%  77 Train accuracy: 0.914
# 95%  78 Train accuracy: 0.914
# 95%  79 Train accuracy: 0.915
# 95%  80 Train accuracy: 0.916
# 95%  81 Train accuracy: 0.917
# 95%  82 Train accuracy: 0.917
# 95%  83 Train accuracy: 0.918
# 95%  84 Train accuracy: 0.919
# 95%  85 Train accuracy: 0.919
# 95%  86 Train accuracy: 0.919
# 95%  87 Train accuracy: 0.919
# 95%  88 Train accuracy: 0.919
# 95%  89 Train accuracy: 0.921
# 95%  90 Train accuracy: 0.921
# 95%  91 Train accuracy: 0.922
# 95%  92 Train accuracy: 0.922
# 95%  93 Train accuracy: 0.923
# 95%  94 Train accuracy: 0.923
# 95%  95 Train accuracy: 0.923
# 95%  96 Train accuracy: 0.924
# 95%  97 Train accuracy: 0.924
# 95%  98 Train accuracy: 0.924
# 95%  99 Train accuracy: 0.924

# %%
tf.reset_default_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

from tensorflow.contrib.layers import fully_connected

with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1", activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2", activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")      
        
    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")   
    

with tf.name_scope("train"):
    initial_learning_rate = 0.1
    decay_steps = 10000
    decay_rate = 1/10
    global_step = tf.Variable(0, trainable=False, name="global_step")
    learning_rate = tf.train.exponential_decay(initial_learning_rate, global_step,
                                               decay_steps, decay_rate)
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)    
    
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))    
    
    
init = tf.global_variables_initializer()


with tf.Session() as sess:
    sess.run(init)
    for epoch in range(n_epochs):
        for batch_index in range(data_X.shape[0] // batch_size):
            print("\r{}%".format(100 * batch_index //  (data_X.shape[0] // batch_size) ), end="")
            
            shuffle_index = np.random.permutation(batch_size)
            X_batch, y_batch = data_X[shuffle_index], data_y[shuffle_index]
            
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: data_X, y: data_y})
        print(" ", epoch, "Train accuracy:", acc_train) 
        array_acc_test_g_s.append(acc_train)
# Out:
# 95%  0 Train accuracy: 0.857
# 95%  1 Train accuracy: 0.88
# 95%  2 Train accuracy: 0.897
# 95%  3 Train accuracy: 0.911
# 95%  4 Train accuracy: 0.914
# 95%  5 Train accuracy: 0.912
# 95%  6 Train accuracy: 0.913
# 95%  7 Train accuracy: 0.914
# 95%  8 Train accuracy: 0.919
# 95%  9 Train accuracy: 0.921
# 95%  10 Train accuracy: 0.924
# 95%  11 Train accuracy: 0.926
# 95%  12 Train accuracy: 0.932
# 95%  13 Train accuracy: 0.937
# 95%  14 Train accuracy: 0.939
# 95%  15 Train accuracy: 0.941
# 95%  16 Train accuracy: 0.944
# 95%  17 Train accuracy: 0.946
# 95%  18 Train accuracy: 0.948
# 95%  19 Train accuracy: 0.953
# 95%  20 Train accuracy: 0.956
# 95%  21 Train accuracy: 0.959
# 95%  22 Train accuracy: 0.962
# 95%  23 Train accuracy: 0.963
# 95%  24 Train accuracy: 0.963
# 95%  25 Train accuracy: 0.965
# 95%  26 Train accuracy: 0.966
# 95%  27 Train accuracy: 0.968
# 95%  28 Train accuracy: 0.969
# 95%  29 Train accuracy: 0.97
# 95%  30 Train accuracy: 0.97
# 95%  31 Train accuracy: 0.97
# 95%  32 Train accuracy: 0.97
# 95%  33 Train accuracy: 0.97
# 95%  34 Train accuracy: 0.97
# 95%  35 Train accuracy: 0.972
# 95%  36 Train accuracy: 0.972
# 95%  37 Train accuracy: 0.973
# 95%  38 Train accuracy: 0.974
# 95%  39 Train accuracy: 0.974
# 95%  40 Train accuracy: 0.974
# 95%  41 Train accuracy: 0.974
# 95%  42 Train accuracy: 0.975
# 95%  43 Train accuracy: 0.975
# 95%  44 Train accuracy: 0.975
# 95%  45 Train accuracy: 0.975
# 95%  46 Train accuracy: 0.976
# 95%  47 Train accuracy: 0.976
# 95%  48 Train accuracy: 0.976
# 95%  49 Train accuracy: 0.976
# 95%  50 Train accuracy: 0.976
# 95%  51 Train accuracy: 0.976
# 95%  52 Train accuracy: 0.976
# 95%  53 Train accuracy: 0.976
# 95%  54 Train accuracy: 0.977
# 95%  55 Train accuracy: 0.977
# 95%  56 Train accuracy: 0.978
# 95%  57 Train accuracy: 0.978
# 95%  58 Train accuracy: 0.978
# 95%  59 Train accuracy: 0.978
# 95%  60 Train accuracy: 0.979
# 95%  61 Train accuracy: 0.979
# 95%  62 Train accuracy: 0.979
# 95%  63 Train accuracy: 0.979
# 95%  64 Train accuracy: 0.979
# 95%  65 Train accuracy: 0.98
# 95%  66 Train accuracy: 0.98
# 95%  67 Train accuracy: 0.98
# 95%  68 Train accuracy: 0.98
# 95%  69 Train accuracy: 0.98
# 95%  70 Train accuracy: 0.98
# 95%  71 Train accuracy: 0.98
# 95%  72 Train accuracy: 0.98
# 95%  73 Train accuracy: 0.98
# 95%  74 Train accuracy: 0.98
# 95%  75 Train accuracy: 0.98
# 95%  76 Train accuracy: 0.98
# 95%  77 Train accuracy: 0.98
# 95%  78 Train accuracy: 0.98
# 95%  79 Train accuracy: 0.98
# 95%  80 Train accuracy: 0.98
# 95%  81 Train accuracy: 0.98
# 95%  82 Train accuracy: 0.98
# 95%  83 Train accuracy: 0.98
# 95%  84 Train accuracy: 0.98
# 95%  85 Train accuracy: 0.98
# 95%  86 Train accuracy: 0.98
# 95%  87 Train accuracy: 0.98
# 95%  88 Train accuracy: 0.98
# 95%  89 Train accuracy: 0.98
# 95%  90 Train accuracy: 0.98
# 95%  91 Train accuracy: 0.98
# 95%  92 Train accuracy: 0.98
# 95%  93 Train accuracy: 0.981
# 95%  94 Train accuracy: 0.981
# 95%  95 Train accuracy: 0.982
# 95%  96 Train accuracy: 0.982
# 95%  97 Train accuracy: 0.983
# 95%  98 Train accuracy: 0.983
# 95%  99 Train accuracy: 0.983

# %%
learning_rate = 0.01

# %%
tf.reset_default_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

from tensorflow.contrib.layers import fully_connected

with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1", activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2", activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")      
        
    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")   
    

with tf.name_scope("train"):
    optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate,
                                       momentum=0.9)
    training_op = optimizer.minimize(loss)    
    
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))    
    
    
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(n_epochs):
        for batch_index in range(data_X.shape[0] // batch_size):
            print("\r{}%".format(100 * batch_index //  (data_X.shape[0] // batch_size) ), end="")
            
            shuffle_index = np.random.permutation(batch_size)
            X_batch, y_batch = data_X[shuffle_index], data_y[shuffle_index]
            
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: data_X, y: data_y})
        print(" ", epoch, "Train accuracy:", acc_train) 
        array_acc_test_momentum.append(acc_train)
# Out:
# 95%  0 Train accuracy: 0.781
# 95%  1 Train accuracy: 0.819
# 95%  2 Train accuracy: 0.854
# 95%  3 Train accuracy: 0.878
# 95%  4 Train accuracy: 0.899
# 95%  5 Train accuracy: 0.906
# 95%  6 Train accuracy: 0.908
# 95%  7 Train accuracy: 0.907
# 95%  8 Train accuracy: 0.908
# 95%  9 Train accuracy: 0.911
# 95%  10 Train accuracy: 0.916
# 95%  11 Train accuracy: 0.919
# 95%  12 Train accuracy: 0.919
# 95%  13 Train accuracy: 0.923
# 95%  14 Train accuracy: 0.929
# 95%  15 Train accuracy: 0.933
# 95%  16 Train accuracy: 0.937
# 95%  17 Train accuracy: 0.938
# 95%  18 Train accuracy: 0.942
# 95%  19 Train accuracy: 0.944
# 95%  20 Train accuracy: 0.946
# 95%  21 Train accuracy: 0.948
# 95%  22 Train accuracy: 0.952
# 95%  23 Train accuracy: 0.956
# 95%  24 Train accuracy: 0.957
# 95%  25 Train accuracy: 0.96
# 95%  26 Train accuracy: 0.962
# 95%  27 Train accuracy: 0.962
# 95%  28 Train accuracy: 0.963
# 95%  29 Train accuracy: 0.965
# 95%  30 Train accuracy: 0.967
# 95%  31 Train accuracy: 0.968
# 95%  32 Train accuracy: 0.969
# 95%  33 Train accuracy: 0.969
# 95%  34 Train accuracy: 0.969
# 95%  35 Train accuracy: 0.97
# 95%  36 Train accuracy: 0.97
# 95%  37 Train accuracy: 0.97
# 95%  38 Train accuracy: 0.97
# 95%  39 Train accuracy: 0.971
# 95%  40 Train accuracy: 0.972
# 95%  41 Train accuracy: 0.972
# 95%  42 Train accuracy: 0.972
# 95%  43 Train accuracy: 0.972
# 95%  44 Train accuracy: 0.972
# 95%  45 Train accuracy: 0.974
# 95%  46 Train accuracy: 0.975
# 95%  47 Train accuracy: 0.975
# 95%  48 Train accuracy: 0.975
# 95%  49 Train accuracy: 0.975
# 95%  50 Train accuracy: 0.975
# 95%  51 Train accuracy: 0.975
# 95%  52 Train accuracy: 0.975
# 95%  53 Train accuracy: 0.975
# 95%  54 Train accuracy: 0.976
# 95%  55 Train accuracy: 0.976
# 95%  56 Train accuracy: 0.976
# 95%  57 Train accuracy: 0.976
# 95%  58 Train accuracy: 0.976
# 95%  59 Train accuracy: 0.976
# 95%  60 Train accuracy: 0.976
# 95%  61 Train accuracy: 0.976
# 95%  62 Train accuracy: 0.976
# 95%  63 Train accuracy: 0.976
# 95%  64 Train accuracy: 0.976
# 95%  65 Train accuracy: 0.978
# 95%  66 Train accuracy: 0.978
# 95%  67 Train accuracy: 0.978
# 95%  68 Train accuracy: 0.978
# 95%  69 Train accuracy: 0.978
# 95%  70 Train accuracy: 0.978
# 95%  71 Train accuracy: 0.979
# 95%  72 Train accuracy: 0.979
# 95%  73 Train accuracy: 0.979
# 95%  74 Train accuracy: 0.979
# 95%  75 Train accuracy: 0.979
# 95%  76 Train accuracy: 0.979
# 95%  77 Train accuracy: 0.979
# 95%  78 Train accuracy: 0.979
# 95%  79 Train accuracy: 0.979
# 95%  80 Train accuracy: 0.979
# 95%  81 Train accuracy: 0.979
# 95%  82 Train accuracy: 0.979
# 95%  83 Train accuracy: 0.979
# 95%  84 Train accuracy: 0.979
# 95%  85 Train accuracy: 0.979
# 95%  86 Train accuracy: 0.979
# 95%  87 Train accuracy: 0.979
# 95%  88 Train accuracy: 0.979
# 95%  89 Train accuracy: 0.979
# 95%  90 Train accuracy: 0.979
# 95%  91 Train accuracy: 0.979
# 95%  92 Train accuracy: 0.979
# 95%  93 Train accuracy: 0.979
# 95%  94 Train accuracy: 0.98
# 95%  95 Train accuracy: 0.98
# 95%  96 Train accuracy: 0.98
# 95%  97 Train accuracy: 0.98
# 95%  98 Train accuracy: 0.98
# 95%  99 Train accuracy: 0.98

# %%
tf.reset_default_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

from tensorflow.contrib.layers import fully_connected

with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1", activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2", activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")      
        
    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")   

with tf.name_scope("train"):
    optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate,
                                       momentum=0.9, use_nesterov=True)
    training_op = optimizer.minimize(loss)    
    
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))    
    
    
init = tf.global_variables_initializer()


with tf.Session() as sess:
    sess.run(init)
    for epoch in range(n_epochs):
        for batch_index in range(data_X.shape[0] // batch_size):
            print("\r{}%".format(100 * batch_index //  (data_X.shape[0] // batch_size) ), end="")
            
            shuffle_index = np.random.permutation(batch_size)
            X_batch, y_batch = data_X[shuffle_index], data_y[shuffle_index]
            
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: data_X, y: data_y})
        print(" ", epoch, "Train accuracy:", acc_train) 
        array_acc_test_nesterov.append(acc_train)
# Out:
# 95%  0 Train accuracy: 0.842
# 95%  1 Train accuracy: 0.859
# 95%  2 Train accuracy: 0.879
# 95%  3 Train accuracy: 0.903
# 95%  4 Train accuracy: 0.909
# 95%  5 Train accuracy: 0.907
# 95%  6 Train accuracy: 0.907
# 95%  7 Train accuracy: 0.912
# 95%  8 Train accuracy: 0.915
# 95%  9 Train accuracy: 0.917
# 95%  10 Train accuracy: 0.919
# 95%  11 Train accuracy: 0.922
# 95%  12 Train accuracy: 0.927
# 95%  13 Train accuracy: 0.932
# 95%  14 Train accuracy: 0.937
# 95%  15 Train accuracy: 0.938
# 95%  16 Train accuracy: 0.939
# 95%  17 Train accuracy: 0.943
# 95%  18 Train accuracy: 0.945
# 95%  19 Train accuracy: 0.946
# 95%  20 Train accuracy: 0.949
# 95%  21 Train accuracy: 0.952
# 95%  22 Train accuracy: 0.956
# 95%  23 Train accuracy: 0.957
# 95%  24 Train accuracy: 0.96
# 95%  25 Train accuracy: 0.962
# 95%  26 Train accuracy: 0.962
# 95%  27 Train accuracy: 0.963
# 95%  28 Train accuracy: 0.964
# 95%  29 Train accuracy: 0.966
# 95%  30 Train accuracy: 0.967
# 95%  31 Train accuracy: 0.968
# 95%  32 Train accuracy: 0.969
# 95%  33 Train accuracy: 0.969
# 95%  34 Train accuracy: 0.969
# 95%  35 Train accuracy: 0.969
# 95%  36 Train accuracy: 0.97
# 95%  37 Train accuracy: 0.97
# 95%  38 Train accuracy: 0.97
# 95%  39 Train accuracy: 0.97
# 95%  40 Train accuracy: 0.971
# 95%  41 Train accuracy: 0.972
# 95%  42 Train accuracy: 0.972
# 95%  43 Train accuracy: 0.972
# 95%  44 Train accuracy: 0.972
# 95%  45 Train accuracy: 0.972
# 95%  46 Train accuracy: 0.972
# 95%  47 Train accuracy: 0.973
# 95%  48 Train accuracy: 0.974
# 95%  49 Train accuracy: 0.974
# 95%  50 Train accuracy: 0.975
# 95%  51 Train accuracy: 0.975
# 95%  52 Train accuracy: 0.975
# 95%  53 Train accuracy: 0.975
# 95%  54 Train accuracy: 0.975
# 95%  55 Train accuracy: 0.975
# 95%  56 Train accuracy: 0.975
# 95%  57 Train accuracy: 0.975
# 95%  58 Train accuracy: 0.975
# 95%  59 Train accuracy: 0.975
# 95%  60 Train accuracy: 0.975
# 95%  61 Train accuracy: 0.976
# 95%  62 Train accuracy: 0.976
# 95%  63 Train accuracy: 0.976
# 95%  64 Train accuracy: 0.976
# 95%  65 Train accuracy: 0.976
# 95%  66 Train accuracy: 0.976
# 95%  67 Train accuracy: 0.976
# 95%  68 Train accuracy: 0.976
# 95%  69 Train accuracy: 0.976
# 95%  70 Train accuracy: 0.976
# 95%  71 Train accuracy: 0.976
# 95%  72 Train accuracy: 0.976
# 95%  73 Train accuracy: 0.976
# 95%  74 Train accuracy: 0.977
# 95%  75 Train accuracy: 0.977
# 95%  76 Train accuracy: 0.977
# 95%  77 Train accuracy: 0.977
# 95%  78 Train accuracy: 0.977
# 95%  79 Train accuracy: 0.977
# 95%  80 Train accuracy: 0.978
# 95%  81 Train accuracy: 0.978
# 95%  82 Train accuracy: 0.978
# 95%  83 Train accuracy: 0.978
# 95%  84 Train accuracy: 0.978
# 95%  85 Train accuracy: 0.978
# 95%  86 Train accuracy: 0.978
# 95%  87 Train accuracy: 0.978
# 95%  88 Train accuracy: 0.978
# 95%  89 Train accuracy: 0.979
# 95%  90 Train accuracy: 0.979
# 95%  91 Train accuracy: 0.979
# 95%  92 Train accuracy: 0.979
# 95%  93 Train accuracy: 0.979
# 95%  94 Train accuracy: 0.979
# 95%  95 Train accuracy: 0.979
# 95%  96 Train accuracy: 0.979
# 95%  97 Train accuracy: 0.979
# 95%  98 Train accuracy: 0.979
# 95%  99 Train accuracy: 0.979

# %%
tf.reset_default_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

from tensorflow.contrib.layers import fully_connected

with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1", activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2", activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")      
        
    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")   

with tf.name_scope("train"):
    optimizer = tf.train.AdagradOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)    
    
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))    
    
    
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(n_epochs):
        for batch_index in range(data_X.shape[0] // batch_size):
            print("\r{}%".format(100 * batch_index //  (data_X.shape[0] // batch_size) ), end="")
            
            shuffle_index = np.random.permutation(batch_size)
            X_batch, y_batch = data_X[shuffle_index], data_y[shuffle_index]
            
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: data_X, y: data_y})
        print(" ", epoch, "Train accuracy:", acc_train) 
        array_acc_test_ada_grad.append(acc_train)
# Out:
# 95%  0 Train accuracy: 0.84
# 95%  1 Train accuracy: 0.836
# 95%  2 Train accuracy: 0.841
# 95%  3 Train accuracy: 0.846
# 95%  4 Train accuracy: 0.853
# 95%  5 Train accuracy: 0.857
# 95%  6 Train accuracy: 0.863
# 95%  7 Train accuracy: 0.875
# 95%  8 Train accuracy: 0.88
# 95%  9 Train accuracy: 0.888
# 95%  10 Train accuracy: 0.89
# 95%  11 Train accuracy: 0.891
# 95%  12 Train accuracy: 0.895
# 95%  13 Train accuracy: 0.9
# 95%  14 Train accuracy: 0.901
# 95%  15 Train accuracy: 0.906
# 95%  16 Train accuracy: 0.91
# 95%  17 Train accuracy: 0.911
# 95%  18 Train accuracy: 0.914
# 95%  19 Train accuracy: 0.912
# 95%  20 Train accuracy: 0.913
# 95%  21 Train accuracy: 0.913
# 95%  22 Train accuracy: 0.913
# 95%  23 Train accuracy: 0.913
# 95%  24 Train accuracy: 0.913
# 95%  25 Train accuracy: 0.913
# 95%  26 Train accuracy: 0.915
# 95%  27 Train accuracy: 0.916
# 95%  28 Train accuracy: 0.917
# 95%  29 Train accuracy: 0.919
# 95%  30 Train accuracy: 0.92
# 95%  31 Train accuracy: 0.922
# 95%  32 Train accuracy: 0.923
# 95%  33 Train accuracy: 0.924
# 95%  34 Train accuracy: 0.925
# 95%  35 Train accuracy: 0.926
# 95%  36 Train accuracy: 0.927
# 95%  37 Train accuracy: 0.928
# 95%  38 Train accuracy: 0.929
# 95%  39 Train accuracy: 0.93
# 95%  40 Train accuracy: 0.932
# 95%  41 Train accuracy: 0.936
# 95%  42 Train accuracy: 0.937
# 95%  43 Train accuracy: 0.937
# 95%  44 Train accuracy: 0.937
# 95%  45 Train accuracy: 0.937
# 95%  46 Train accuracy: 0.939
# 95%  47 Train accuracy: 0.939
# 95%  48 Train accuracy: 0.939
# 95%  49 Train accuracy: 0.941
# 95%  50 Train accuracy: 0.942
# 95%  51 Train accuracy: 0.943
# 95%  52 Train accuracy: 0.944
# 95%  53 Train accuracy: 0.944
# 95%  54 Train accuracy: 0.944
# 95%  55 Train accuracy: 0.944
# 95%  56 Train accuracy: 0.945
# 95%  57 Train accuracy: 0.945
# 95%  58 Train accuracy: 0.945
# 95%  59 Train accuracy: 0.946
# 95%  60 Train accuracy: 0.947
# 95%  61 Train accuracy: 0.947
# 95%  62 Train accuracy: 0.948
# 95%  63 Train accuracy: 0.948
# 95%  64 Train accuracy: 0.949
# 95%  65 Train accuracy: 0.949
# 95%  66 Train accuracy: 0.949
# 95%  67 Train accuracy: 0.949
# 95%  68 Train accuracy: 0.953
# 95%  69 Train accuracy: 0.954
# 95%  70 Train accuracy: 0.954
# 95%  71 Train accuracy: 0.955
# 95%  72 Train accuracy: 0.956
# 95%  73 Train accuracy: 0.956
# 95%  74 Train accuracy: 0.957
# 95%  75 Train accuracy: 0.957
# 95%  76 Train accuracy: 0.957
# 95%  77 Train accuracy: 0.958
# 95%  78 Train accuracy: 0.959
# 95%  79 Train accuracy: 0.96
# 95%  80 Train accuracy: 0.961
# 95%  81 Train accuracy: 0.962
# 95%  82 Train accuracy: 0.962
# 95%  83 Train accuracy: 0.962
# 95%  84 Train accuracy: 0.962
# 95%  85 Train accuracy: 0.962
# 95%  86 Train accuracy: 0.962
# 95%  87 Train accuracy: 0.962
# 95%  88 Train accuracy: 0.962
# 95%  89 Train accuracy: 0.963
# 95%  90 Train accuracy: 0.963
# 95%  91 Train accuracy: 0.963
# 95%  92 Train accuracy: 0.963
# 95%  93 Train accuracy: 0.963
# 95%  94 Train accuracy: 0.964
# 95%  95 Train accuracy: 0.964
# 95%  96 Train accuracy: 0.965
# 95%  97 Train accuracy: 0.965
# 95%  98 Train accuracy: 0.965
# 95%  99 Train accuracy: 0.965

# %%
tf.reset_default_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

from tensorflow.contrib.layers import fully_connected

with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1", activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2", activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")      
        
    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")   
    

with tf.name_scope("train"):
    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate,
                                      momentum=0.9, decay=0.9, epsilon=1e-10)
    training_op = optimizer.minimize(loss)    
    
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))    
    
    
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(n_epochs):
        for batch_index in range(data_X.shape[0] // batch_size):
            print("\r{}%".format(100 * batch_index //  (data_X.shape[0] // batch_size) ), end="")
            
            shuffle_index = np.random.permutation(batch_size)
            X_batch, y_batch = data_X[shuffle_index], data_y[shuffle_index]
            
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: data_X, y: data_y})
        print(" ", epoch, "Train accuracy:", acc_train) 
        array_acc_test_RMS_prop.append(acc_train)
# Out:
# 95%  0 Train accuracy: 0.831
# 95%  1 Train accuracy: 0.903
# 95%  2 Train accuracy: 0.917
# 95%  3 Train accuracy: 0.983
# 95%  4 Train accuracy: 0.991
# 95%  5 Train accuracy: 0.989
# 95%  6 Train accuracy: 0.989
# 95%  7 Train accuracy: 0.99
# 95%  8 Train accuracy: 0.991
# 95%  9 Train accuracy: 0.992
# 95%  10 Train accuracy: 0.993
# 95%  11 Train accuracy: 0.993
# 95%  12 Train accuracy: 0.993
# 95%  13 Train accuracy: 0.994
# 95%  14 Train accuracy: 0.994
# 95%  15 Train accuracy: 0.994
# 95%  16 Train accuracy: 0.994
# 95%  17 Train accuracy: 0.994
# 95%  18 Train accuracy: 0.994
# 95%  19 Train accuracy: 0.994
# 95%  20 Train accuracy: 0.994
# 95%  21 Train accuracy: 0.994
# 95%  22 Train accuracy: 0.994
# 95%  23 Train accuracy: 0.994
# 95%  24 Train accuracy: 0.994
# 95%  25 Train accuracy: 0.994
# 95%  26 Train accuracy: 0.994
# 95%  27 Train accuracy: 0.994
# 95%  28 Train accuracy: 0.994
# 95%  29 Train accuracy: 0.994
# 95%  30 Train accuracy: 0.994
# 95%  31 Train accuracy: 0.994
# 95%  32 Train accuracy: 0.994
# 95%  33 Train accuracy: 0.995
# 95%  34 Train accuracy: 0.995
# 95%  35 Train accuracy: 0.995
# 95%  36 Train accuracy: 0.995
# 95%  37 Train accuracy: 0.995
# 95%  38 Train accuracy: 0.995
# 95%  39 Train accuracy: 0.995
# 95%  40 Train accuracy: 0.994
# 95%  41 Train accuracy: 0.994
# 95%  42 Train accuracy: 0.994
# 95%  43 Train accuracy: 0.994
# 95%  44 Train accuracy: 0.994
# 95%  45 Train accuracy: 0.994
# 95%  46 Train accuracy: 0.994
# 95%  47 Train accuracy: 0.994
# 95%  48 Train accuracy: 0.994
# 95%  49 Train accuracy: 0.994
# 95%  50 Train accuracy: 0.994
# 95%  51 Train accuracy: 0.994
# 95%  52 Train accuracy: 0.994
# 95%  53 Train accuracy: 0.994
# 95%  54 Train accuracy: 0.994
# 95%  55 Train accuracy: 0.994
# 95%  56 Train accuracy: 0.994
# 95%  57 Train accuracy: 0.994
# 95%  58 Train accuracy: 0.994
# 95%  59 Train accuracy: 0.994
# 95%  60 Train accuracy: 0.994
# 95%  61 Train accuracy: 0.994
# 95%  62 Train accuracy: 0.994
# 95%  63 Train accuracy: 0.994
# 95%  64 Train accuracy: 0.994
# 95%  65 Train accuracy: 0.994
# 95%  66 Train accuracy: 0.994
# 95%  67 Train accuracy: 0.994
# 95%  68 Train accuracy: 0.994
# 95%  69 Train accuracy: 0.994
# 95%  70 Train accuracy: 0.994
# 95%  71 Train accuracy: 0.994
# 95%  72 Train accuracy: 0.994
# 95%  73 Train accuracy: 0.994
# 95%  74 Train accuracy: 0.994
# 95%  75 Train accuracy: 0.994
# 95%  76 Train accuracy: 0.994
# 95%  77 Train accuracy: 0.994
# 95%  78 Train accuracy: 0.995
# 95%  79 Train accuracy: 0.995
# 95%  80 Train accuracy: 0.995
# 95%  81 Train accuracy: 0.995
# 95%  82 Train accuracy: 0.995
# 95%  83 Train accuracy: 0.995
# 95%  84 Train accuracy: 0.995
# 95%  85 Train accuracy: 0.995
# 95%  86 Train accuracy: 0.995
# 95%  87 Train accuracy: 0.995
# 95%  88 Train accuracy: 0.995
# 95%  89 Train accuracy: 0.995
# 95%  90 Train accuracy: 0.995
# 95%  91 Train accuracy: 0.995
# 95%  92 Train accuracy: 0.995
# 95%  93 Train accuracy: 0.995
# 95%  94 Train accuracy: 0.995
# 95%  95 Train accuracy: 0.995
# 95%  96 Train accuracy: 0.995
# 95%  97 Train accuracy: 0.995
# 95%  98 Train accuracy: 0.995
# 95%  99 Train accuracy: 0.995

# %%
tf.reset_default_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

from tensorflow.contrib.layers import fully_connected

with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1", activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2", activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")      
        
    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")   
    
with tf.name_scope("train"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)    
    
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))    
    
    
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(n_epochs):
        for batch_index in range(data_X.shape[0] // batch_size):
            print("\r{}%".format(100 * batch_index //  (data_X.shape[0] // batch_size) ), end="")
            
            shuffle_index = np.random.permutation(batch_size)
            X_batch, y_batch = data_X[shuffle_index], data_y[shuffle_index]
            
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: data_X, y: data_y})
        print(" ", epoch, "Train accuracy:", acc_train) 
        array_acc_test_adam.append(acc_train)
# Out:
# 95%  0 Train accuracy: 0.924
# 95%  1 Train accuracy: 0.969
# 95%  2 Train accuracy: 0.974
# 95%  3 Train accuracy: 0.975
# 95%  4 Train accuracy: 0.975
# 95%  5 Train accuracy: 0.974
# 95%  6 Train accuracy: 0.974
# 95%  7 Train accuracy: 0.974
# 95%  8 Train accuracy: 0.974
# 95%  9 Train accuracy: 0.975
# 95%  10 Train accuracy: 0.975
# 95%  11 Train accuracy: 0.975
# 95%  12 Train accuracy: 0.975
# 95%  13 Train accuracy: 0.975
# 95%  14 Train accuracy: 0.975
# 95%  15 Train accuracy: 0.975
# 95%  16 Train accuracy: 0.975
# 95%  17 Train accuracy: 0.975
# 95%  18 Train accuracy: 0.975
# 95%  19 Train accuracy: 0.975
# 95%  20 Train accuracy: 0.975
# 95%  21 Train accuracy: 0.975
# 95%  22 Train accuracy: 0.975
# 95%  23 Train accuracy: 0.975
# 95%  24 Train accuracy: 0.975
# 95%  25 Train accuracy: 0.975
# 95%  26 Train accuracy: 0.975
# 95%  27 Train accuracy: 0.976
# 95%  28 Train accuracy: 0.976
# 95%  29 Train accuracy: 0.976
# 95%  30 Train accuracy: 0.976
# 95%  31 Train accuracy: 0.976
# 95%  32 Train accuracy: 0.976
# 95%  33 Train accuracy: 0.976
# 95%  34 Train accuracy: 0.976
# 95%  35 Train accuracy: 0.976
# 95%  36 Train accuracy: 0.976
# 95%  37 Train accuracy: 0.976
# 95%  38 Train accuracy: 0.976
# 95%  39 Train accuracy: 0.977
# 95%  40 Train accuracy: 0.977
# 95%  41 Train accuracy: 0.977
# 95%  42 Train accuracy: 0.977
# 95%  43 Train accuracy: 0.977
# 95%  44 Train accuracy: 0.977
# 95%  45 Train accuracy: 0.977
# 95%  46 Train accuracy: 0.977
# 95%  47 Train accuracy: 0.977
# 95%  48 Train accuracy: 0.977
# 95%  49 Train accuracy: 0.977
# 95%  50 Train accuracy: 0.977
# 95%  51 Train accuracy: 0.977
# 95%  52 Train accuracy: 0.977
# 95%  53 Train accuracy: 0.977
# 95%  54 Train accuracy: 0.977
# 95%  55 Train accuracy: 0.977
# 95%  56 Train accuracy: 0.977
# 95%  57 Train accuracy: 0.977
# 95%  58 Train accuracy: 0.977
# 95%  59 Train accuracy: 0.977
# 95%  60 Train accuracy: 0.977
# 95%  61 Train accuracy: 0.977
# 95%  62 Train accuracy: 0.977
# 95%  63 Train accuracy: 0.977
# 95%  64 Train accuracy: 0.977
# 95%  65 Train accuracy: 0.977
# 95%  66 Train accuracy: 0.977
# 95%  67 Train accuracy: 0.977
# 95%  68 Train accuracy: 0.977
# 95%  69 Train accuracy: 0.977
# 95%  70 Train accuracy: 0.977
# 95%  71 Train accuracy: 0.977
# 95%  72 Train accuracy: 0.977
# 95%  73 Train accuracy: 0.977
# 95%  74 Train accuracy: 0.977
# 95%  75 Train accuracy: 0.977
# 95%  76 Train accuracy: 0.977
# 95%  77 Train accuracy: 0.977
# 95%  78 Train accuracy: 0.977
# 95%  79 Train accuracy: 0.977
# 95%  80 Train accuracy: 0.977
# 95%  81 Train accuracy: 0.977
# 95%  82 Train accuracy: 0.977
# 95%  83 Train accuracy: 0.977
# 95%  84 Train accuracy: 0.977
# 95%  85 Train accuracy: 0.977
# 95%  86 Train accuracy: 0.977
# 95%  87 Train accuracy: 0.977
# 95%  88 Train accuracy: 0.977
# 95%  89 Train accuracy: 0.977
# 95%  90 Train accuracy: 0.977
# 95%  91 Train accuracy: 0.977
# 95%  92 Train accuracy: 0.977
# 95%  93 Train accuracy: 0.977
# 95%  94 Train accuracy: 0.978
# 95%  95 Train accuracy: 0.978
# 95%  96 Train accuracy: 0.978
# 95%  97 Train accuracy: 0.978
# 95%  98 Train accuracy: 0.978
# 95%  99 Train accuracy: 0.978

# %%
plt.figure()
plt.plot(array_acc_test_g, label='Gradient Descent')
plt.plot(array_acc_test_g_s, label='Gradient Descent + Exponential scheduling')
plt.plot(array_acc_test_adam, label='Adam')
plt.ylim(0.7,1.1)
plt.xlabel('Epoch')
plt.ylabel('Accuracy on test set')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(array_acc_test_g, label='Gradient Descent')
plt.plot(array_acc_test_g_s, label='Gradient Descent + Exponential scheduling')
plt.plot(array_acc_test_momentum, label='Momentum')
plt.plot(array_acc_test_nesterov, label='Nesterov')
plt.plot(array_acc_test_ada_grad, label='AdaGrad')
plt.plot(array_acc_test_RMS_prop, label='RMSPropt')
plt.plot(array_acc_test_adam, label='Adam')
plt.ylim(0.7,1.1)
plt.xlabel('Epoch')
plt.ylabel('Accuracy on test set')
plt.legend()
plt.show()
